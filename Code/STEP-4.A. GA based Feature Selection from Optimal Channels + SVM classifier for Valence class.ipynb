# %%
import sys
import warnings
if not sys.warnoptions:
  warnings.simplefilter("ignore")

# %%
! pip install deap
! pip install scoop

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import sklearn.model_selection as model_selection
import pickle, scipy, csv, statistics, math, warnings, joblib, random, numpy
from sklearn import metrics, svm, datasets
from math import log,e, floor
from time import time
from sklearn.svm import SVC, LinearSVC
from sklearn.model_selection import cross_val_score,cross_val_predict,GridSearchCV, train_test_split, StratifiedKFold, KFold, cross_validate, learning_curve
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import plot_confusion_matrix, mean_absolute_error, accuracy_score, r2_score, confusion_matrix, classification_report, f1_score, precision_score, recall_score
from sklearn import metrics, preprocessing, svm
from sklearn.linear_model import LogisticRegression
from deap import creator, base, tools, algorithms
from scoop import futures
from sklearn.utils import shuffle
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def emotion_label(labels, class_label):
	em_labels = []
	if(class_label == "valence"):
		for i in range(0, labels.shape[0]):
			if (labels[i][0]>5): # high valence
				em_labels.append(1)
			else: # low valence
				em_labels.append(0)
		return em_labels
	elif(class_label == "arousal"):
		for i in range(0, labels.shape[0]):
			if (labels[i][1]>5): # high arousal
				em_labels.append(1)
			else: # low arousal
				em_labels.append(0)
		return em_labels
	elif(class_label == "all"):
		for i in range(0, labels.shape[0]):
			if (labels[i][0]>5): # high valence
				if(labels[i][1]>5): # high arousal
					em_labels.append(1) # HVHA
				else:
					em_labels.append(0) # HVLA
			else: # low valence
				if(labels[i][1]>5): # high arousal
					em_labels.append(2) # LVHA
				else: # low arousal
					em_labels.append(3) # LVLA
		return em_labels

# %%
def kfold(allFeatures, allClasses, index):
    m = int(allClasses.shape[0])
    s = int(m/10)
    train_index = np.ones(m-s+1).astype(int)
    test_index  = np.ones(s).astype(int)
    for i in range(s*index,s*(index+1)):
        test_index[i-s*index] = i
    for i in range(0,s*index):
        train_index[i] = i
    for i in range(s + s*index,m):
        train_index[i-s] = i
    X_train = allFeatures.iloc[train_index]
    X_test = allFeatures.iloc[test_index]
    y_train = allClasses[train_index]
    y_test = allClasses[test_index]
    # normalize the xtrain data only with class labels
    return X_train, X_test, y_train, y_test

# %%
# Feature subset fitness function
def getFitness(individual, X_train, X_test, y_train, y_test):
    """
    parse our feature columns that we don't use
    apply one hot encoding to the features.
    """
    cols = [index for index in range(len(individual)) if individual[index] == 0]
    X_trainParsed = X_train.drop(X_train.columns[cols], axis=1)
    X_trainOhFeatures = pd.get_dummies(X_trainParsed)
    X_testParsed = X_test.drop(X_test.columns[cols], axis=1)
    X_testOhFeatures = pd.get_dummies(X_testParsed)

    # Remove any columns that aren't in both the training and test sets
    sharedFeatures = set(X_trainOhFeatures.columns) & set(X_testOhFeatures.columns)
    removeFromTrain = set(X_trainOhFeatures.columns) - sharedFeatures
    removeFromTest = set(X_testOhFeatures.columns) - sharedFeatures
    X_trainOhFeatures = X_trainOhFeatures.drop(list(removeFromTrain), axis=1)
    X_testOhFeatures = X_testOhFeatures.drop(list(removeFromTest), axis=1)

    # Apply logistic regression on the data, and calculate accuracy
    clf = svm.SVC(kernel='poly').fit(X_trainOhFeatures, y_train)
    predictions = clf.predict(X_testOhFeatures)
    accuracy = accuracy_score(y_test, predictions)*100
    return (accuracy,)

# %%
def getFitness_all(individual, X_train, X_test, y_train, y_test):
    """
    Feature subset fitness function
    Parse our feature columns that we don't use
    Apply one hot encoding to the features.
    """
    cols = [index for index in range(len(individual)) if individual[index] == 0]
    #print(cols)
    #print(cols.shape)
    X_trainParsed = X_train.drop(X_train.columns[cols], axis=1)
    X_trainOhFeatures = pd.get_dummies(X_trainParsed)
    X_testParsed = X_test.drop(X_test.columns[cols], axis=1)
    X_testOhFeatures = pd.get_dummies(X_testParsed)

    # Remove any columns that aren't in both the training and test sets
    sharedFeatures = set(X_trainOhFeatures.columns) & set(X_testOhFeatures.columns)
    removeFromTrain = set(X_trainOhFeatures.columns) - sharedFeatures
    removeFromTest = set(X_testOhFeatures.columns) - sharedFeatures
    X_trainOhFeatures = X_trainOhFeatures.drop(list(removeFromTrain), axis=1)
    X_testOhFeatures = X_testOhFeatures.drop(list(removeFromTest), axis=1)

    # Apply logistic regression on the data, and calculate accuracy
    clf = svm.SVC(kernel='poly').fit(X_trainOhFeatures, y_train)
    predictions = clf.predict(X_testOhFeatures)
    accuracy = accuracy_score(y_test, predictions)*100
    print("Accuracy Score: ", accuracy)
    try:
      print('Precision Score : ', precision_score(y_test, predictions)*100)
      print('Recall Score : ', recall_score(y_test, predictions)*100)
      print('F1 Score : ', f1_score(y_test, predictions)*100)
      print('Confusion Matrix : \n' + str(confusion_matrix(y_test, predictions)))
    except:
      pass
    return (accuracy, )

# %%
def getHof(toolbox):
    # Initialize variables to use eaSimple
    numPop = 100
    numGen = 50
    pop = toolbox.population(n=numPop)
    hof = tools.HallOfFame(numPop * numGen)
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", numpy.mean)
    stats.register("std", numpy.std)
    stats.register("min", numpy.min)
    stats.register("max", numpy.max)

    # Launch genetic algorithm
    # change the crossover and mutation probability
    pop, log = algorithms.eaSimple(pop, toolbox, cxpb=0.65, mutpb=0.001, ngen=numGen, stats=stats, halloffame=hof, verbose=False)
    # Return the hall of fame
    return hof,log

# %%
def getMetrics(hof, X_train, X_test, y_train, y_test):
    # Get list of percentiles in the hall of fame
    percentileList = [i / (len(hof) - 1) for i in range(len(hof))]
    # Gather fitness data from each percentile
    testAccuracyList = []
    validationAccuracyList = []
    individualList = []
    for individual in hof:
        testAccuracy = individual.fitness.values
        validationAccuracy = getFitness(individual, X_train, X_test, y_train, y_test)
        testAccuracyList.append(testAccuracy[0])
        validationAccuracyList.append(validationAccuracy[0])
        individualList.append(individual)
    #testAccuracyList.reverse()
    #validationAccuracyList.reverse()
    return testAccuracyList, validationAccuracyList, individualList, percentileList

# %%
def drive(subject_name):
  dfData = pd.read_csv('/content/drive/MyDrive/Sequential methods for channel selection/our code/New/' + subject_name + '_valence.csv')
  allFeatures = dfData
  names = allFeatures.columns
  scaler = MinMaxScaler()
  allFeatures = scaler.fit_transform(allFeatures)
  allFeatures = pd.DataFrame(allFeatures, columns=names)
  allFeatures = allFeatures.loc[:, allFeatures.apply(pd.Series.nunique) != 1]
  link = "/content/drive/MyDrive/Deap/" + subject_name + ".dat"
  with open(link, 'rb') as f:
    raw_data = pickle.load(f, encoding = 'latin1')
  labels = raw_data['labels']
  em_labels = emotion_label(labels, 'valence') # get the emotion labels
  allClasses = np.array(em_labels)
  allFeatures, allClasses = shuffle(allFeatures, allClasses, random_state = 40)
  return allFeatures, allClasses

# %%
subject_names = ["s01", "s02", "s03", "s04", "s05", "s06", "s07", "s08", "s09", "s10", "s11", "s12",
                 "s13", "s14", "s15", "s16", "s17", "s18", "s19", "s20", "s21",
                "s22", "s23", "s24", "s25", "s26", "s27", "s28", "s29", "s30", "s31", "s32"]

# %%
def main_code(allFeatures, allClasses):
  for i in range(0, 10):
    print("Fold value = ", i+1)
    print("-"*40)
    #call k fold
    X_train, X_test, y_train, y_test = kfold(allFeatures, allClasses, i)
    #==========================    DEAP GLOBAL VARIABLES (viewable by SCOOP)      ======================
    # Create Individual
    creator.create("FitnessMax", base.Fitness, weights = (1.0,))
    creator.create("Individual", list, fitness = creator.FitnessMax)

    # Create Toolbox
    toolbox = base.Toolbox()
    toolbox.register("attr_bool", random.randint, 0, 1)
    toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.attr_bool, len(allFeatures.columns) - 1)
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    # Continue filling toolbox...
    toolbox.register("evaluate", getFitness, X_train = X_train, X_test = X_test, y_train = y_train, y_test = y_test)
    toolbox.register("mate", tools.cxOnePoint)
    toolbox.register("mutate", tools.mutFlipBit, indpb = 0.05)
    toolbox.register("select", tools.selTournament, tournsize = 7)
    #===================================================================================================
    
    # First, we will apply logistic regression using all the features to acquire a baseline accuracy.
    individual = [1 for i in range(len(allFeatures.columns))]
    Accuracy = getFitness_all(individual, X_train, X_test, y_train, y_test)
    if(Accuracy[0]==100):
      continue
    #print('\nAccuracy with all features from SVM: \t', Accuracy)
    # Now, we will apply a genetic algorithm to choose a subset of features that gives a better accuracy than the baseline.
    hof,log = getHof(toolbox)
    testAccuracyList, validationAccuracyList, individualList, percentileList = getMetrics(hof, X_train, X_test, y_train, y_test)
    # Get a list of subsets that performed best on validation data
    maxValAccSubsetIndicies = [index for index in range(len(validationAccuracyList)) if validationAccuracyList[index] == max(validationAccuracyList)]
    maxValIndividuals = [individualList[index] for index in maxValAccSubsetIndicies]
    maxValSubsets = [[list(allFeatures)[index] for index in range(len(individual)) if individual[index] == 1] for individual in maxValIndividuals]
    acc_list, prec_list, recall_list, f1_list, nooffeatures, conf_mat_list = [], [], [], [], [], []
    print('Optimal Feature Subset(s):')
    for i in range(len(maxValAccSubsetIndicies)):
        nooffeatures.append(len(maxValSubsets[i]))
        x_train = X_train[maxValSubsets[i]]
        x_test = X_test[maxValSubsets[i]]
        # knn implement ga-mlp for this
        #ga_mlp = ag_mlp(x_train , y_train , x_test, y_test, num_epochs = 20, size_mlp = 60, prob_mut = 0.001)
        #y_pred_val = ga_mlp.predict(x_test)
        try:
          clf = svm.SVC(kernel = 'poly').fit(x_train, y_train)
          y_pred_val = clf.predict(x_test)
          acc_list.append(accuracy_score(y_test, y_pred_val)*100)
        except:
          pass
        try:
          #print('Number Features In Subset: \t' + str(len(maxValSubsets[i])) + " ,accuracy: "+str(acc_list[i]))
          prec_list.append(precision_score(y_test,y_pred_val)*100)
          recall_list.append(recall_score(y_test,y_pred_val)*100)
          f1_list.append(f1_score(y_test, y_pred_val)*100)
          conf_mat_list.append(confusion_matrix(y_test, y_pred_val))
        except:
          pass
          # store the accuracy, precission and recall in a list then for each fold
    # convert list to array
    acc_list = np.array(acc_list)
    try:
      prec_list = np.array(prec_list)
      recall_list = np.array(recall_list)
      f1_list = np.array(f1_list)
      conf_mat_list = np.array(conf_mat_list)
      nooffeatures = np.array(nooffeatures)
    except:
      pass
    # find the maximum accuracy
    result = np.where(acc_list == np.amax(acc_list))[0] # now result has all the highest accuracy index
    # check for the precission
    temp_acc = acc_list[result]
    try:
      temp_prec = prec_list[result]
      temp_recall = recall_list[result]
      temp_f1 = f1_list[result]
      temp_conf_mat_list = conf_mat_list[result]
      temp_nooffeatures = nooffeatures[result]
    except:
      continue
    # find max in prec
    result_prec = np.where(temp_prec == np.amax(temp_prec))[0] # stores the index
    # find len of the result_prec
    if (len(result_prec)==1):
      print("Accuracy Score from SVM", temp_acc[result_prec])
      try:
        print('Precision Score : ', temp_prec[result_prec][0])
        if(temp_recall[result_prec][0]==0.0):
          #print
          print(classification_report(y_test, y_pred_val))
        else:
          print('Recall Score : ', temp_recall[result_prec][0])
          print('F1 Score : ', temp_f1[result_prec][0])
          print('Confusion Matrix : \n', temp_conf_mat_list[result_prec][0])
          print('No of features: ', temp_nooffeatures[result_prec][0])
      except:
        pass
    else:
      temp2_acc = temp_acc[result_prec]
      try:
        temp2_prec = temp_prec[result_prec]
        temp2_recall = temp_recall[result_prec]
        temp2_f1 = temp_f1[result_prec]
        temp2_conf_mat_list = temp_conf_mat_list[result_prec]
        temp2_nooffeatures = temp_nooffeatures[result_prec]
        # find the min features in the solution space
      except:
        pass
      final_index = np.where(temp2_nooffeatures == np.amin(temp2_nooffeatures))[0]
      print("Accuracy Score from SVM:", temp_acc[final_index][0])
      try:
        if(temp_prec[final_index][0]==0.0):
          print(classification_report(y_test, y_pred_val))
        else:
          print('Precision Score : ', temp_prec[final_index][0])
          print('Recall Score : ', temp_recall[final_index][0])
          print('F1 Score : ', temp_f1[final_index][0])
          print('Confusion Matrix : \n', temp_conf_mat_list[final_index][0])
          print('No of features: ', temp_nooffeatures[final_index][0])
      except:
        pass
    """
    If multiple solution exists then find which one has the highest precission and that's all
    If there exist multiple solutions which covers those two condition then find which has the minimum no of features in the solution.
    """
    print("-"*40)

# %%
for i in range(0,32):
  print('-'*100)
  print("Subject No: ", subject_names[i])
  print('-'*100)
  allFeatures, allClasses = drive(subject_names[i])
  main_code(allFeatures, allClasses)
# Out:
# ----------------------------------------------------------------------------------------------------
# Subject No:  s01
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  321
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
# [[1 0]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  340
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 1]
#  [0 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  310
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  328
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
# [[1 0]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  335
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  313
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  332
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  354
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  50.0
# Recall Score :  33.33333333333333
# F1 Score :  40.0
# Confusion Matrix :
# [[0 1]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  348
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s02
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  855
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  885
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  919
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  897
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 2]
#  [0 1]]
# No of features:  945
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 2]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[0 2]
#  [0 2]]
# No of features:  881
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 25.0
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.25         4
#    macro avg       0.17      0.25      0.20         4
# weighted avg       0.17      0.25      0.20         4
#
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  869
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 1]
#  [0 2]]
# No of features:  871
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s03
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[4]]
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  188
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  187
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  66.66666666666666
# Recall Score :  66.66666666666666
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 1]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  209
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  189
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  185
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  170
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  196
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s04
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  208
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  190
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 0]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  194
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  213
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 2]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  189
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  186
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  193
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 0]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  183
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  182
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[3 0]
#  [0 1]]
# ----------------------------------------------------------------------------------------------------
# Subject No:  s05
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  1009
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  1018
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  1063
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  100.0
# Recall Score :  25.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 0]
#  [3 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  1006
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[4]]
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  1020
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  1008
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 1]
#  [1 1]]
# No of features:  1027
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 2]
#  [0 1]]
# No of features:  1048
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# ----------------------------------------------------------------------------------------------------
# Subject No:  s06
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  518
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 2]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[0 2]
#  [0 2]]
# No of features:  532
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  568
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 1]
#  [0 3]]
# No of features:  521
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  538
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  572
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 2]
#  [0 1]]
# No of features:  530
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[4]]
# ----------------------------------------------------------------------------------------------------
# Subject No:  s07
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 3]
#  [0 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         4
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.50         4
#    macro avg       0.50      0.25      0.33         4
# weighted avg       1.00      0.50      0.67         4
#
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  538
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  566
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[4]]
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  533
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  531
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  540
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 2]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 1]
#  [0 2]]
# No of features:  530
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  66.66666666666666
# Recall Score :  66.66666666666666
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 1]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 1]
#  [0 3]]
# No of features:  524
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# ----------------------------------------------------------------------------------------------------
# Subject No:  s08
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[4]]
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  33.33333333333333
# Recall Score :  50.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 2]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 1]
#  [0 2]]
# No of features:  1181
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 2]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  1126
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  1125
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  1094
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  66.66666666666666
# Recall Score :  66.66666666666666
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 1]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 0]
#  [1 2]]
# No of features:  1102
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  1094
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s09
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  260
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  260
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  269
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  50.0
# Recall Score :  33.33333333333333
# F1 Score :  40.0
# Confusion Matrix :
# [[0 1]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 0]
#  [1 2]]
# No of features:  260
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  261
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 1]
#  [1 1]]
# No of features:  252
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 0]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.75         4
#    macro avg       0.38      0.50      0.43         4
# weighted avg       0.56      0.75      0.64         4
#
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 1]
#  [1 1]]
# No of features:  255
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  266
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
# [[1 0]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  255
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s10
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[4]]
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  50.0
# Recall Score :  33.33333333333333
# F1 Score :  40.0
# Confusion Matrix :
# [[0 1]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 0]
#  [2 1]]
# No of features:  177
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  182
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 0]
#  [2 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  177
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  189
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  189
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  214
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
# [[1 0]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 0]
#  [1 2]]
# No of features:  218
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  187
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s11
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  249
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  271
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  247
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 1]
#  [0 3]]
# No of features:  257
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  283
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]

# %%
for i in range(10, 32):
  print('-'*100)
  print("Subject No: ", subject_names[i])
  print('-'*100)
  allFeatures, allClasses = drive(subject_names[i])
  main_code(allFeatures, allClasses)
# Out:
# ----------------------------------------------------------------------------------------------------
# Subject No:  s11
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  256
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  247
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  251
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  75.0
# Recall Score :  100.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 1]
#  [0 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  256
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  280
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
# [[1 1]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  268
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 0]
#  [1 2]]
# No of features:  254
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  33.33333333333333
# Recall Score :  100.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 2]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  260
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  50.0
# Recall Score :  33.33333333333333
# F1 Score :  40.0
# Confusion Matrix :
# [[0 1]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  263
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  66.66666666666666
# Recall Score :  66.66666666666666
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 1]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 0]
#  [1 2]]
# No of features:  261
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s12
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  181
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  203
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  191
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  100.0
# Recall Score :  25.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 0]
#  [3 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  197
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  182
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  198
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  226
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 2]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  194
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  191
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s13
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  461
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  483
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[3 0]
#  [0 1]]
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  448
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 1]
#  [0 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  456
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[3 0]
#  [0 1]]
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  461
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  472
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s14
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[3 1]
#  [0 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.50         4
#    macro avg       0.33      0.33      0.33         4
# weighted avg       0.50      0.50      0.50         4
#
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[4]]
# No of features:  388
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  395
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  66.66666666666666
# Recall Score :  100.0
# F1 Score :  80.0
# Confusion Matrix :
#  [[1 1]
#  [0 2]]
# No of features:  450
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  388
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[2 0]
#  [0 2]]
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  403
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
# [[1 0]
#  [0 3]]
# ----------------------------------------------------------------------------------------------------
# Subject No:  s15
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  100.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[4]]
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
# [[0 0]
#  [1 3]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  75.0
# F1 Score :  85.71428571428571
# Confusion Matrix :
#  [[0 0]
#  [1 3]]
# No of features:  116
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  144
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  66.66666666666666
# F1 Score :  80.0
# Confusion Matrix :
# [[1 0]
#  [1 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  134
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 1]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  125
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[2 0]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  130
# ----------------------------------------
# Fold value =  7
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 1]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  125
# ----------------------------------------
# Fold value =  8
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  25.0
# Recall Score :  100.0
# F1 Score :  40.0
# Confusion Matrix :
# [[0 3]
#  [0 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 1]
#  [0 1]]
# No of features:  133
# ----------------------------------------
# Fold value =  9
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  100.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
# [[0 2]
#  [0 2]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[2 0]
#  [0 2]]
# No of features:  112
# ----------------------------------------
# Fold value =  10
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  100.0
# Recall Score :  33.33333333333333
# F1 Score :  50.0
# Confusion Matrix :
# [[1 0]
#  [2 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[1 0]
#  [0 3]]
# No of features:  133
# ----------------------------------------
# ----------------------------------------------------------------------------------------------------
# Subject No:  s16
# ----------------------------------------------------------------------------------------------------
# Fold value =  1
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 1]
#  [1 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 100.0
# Precision Score :  100.0
# Recall Score :  100.0
# F1 Score :  100.0
# Confusion Matrix :
#  [[3 0]
#  [0 1]]
# No of features:  1701
# ----------------------------------------
# Fold value =  2
# ----------------------------------------
# Accuracy Score:  0.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[0 2]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
#  [[1 1]
#  [1 1]]
# No of features:  1669
# ----------------------------------------
# Fold value =  3
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[2 0]
#  [2 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 50.0
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         2
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.50         4
#    macro avg       0.25      0.50      0.33         4
# weighted avg       0.25      0.50      0.33         4
#
# ----------------------------------------
# Fold value =  4
# ----------------------------------------
# Accuracy Score:  50.0
# Precision Score :  50.0
# Recall Score :  50.0
# F1 Score :  50.0
# Confusion Matrix :
# [[1 1]
#  [1 1]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 75.0
# Precision Score :  100.0
# Recall Score :  50.0
# F1 Score :  66.66666666666666
# Confusion Matrix :
#  [[2 0]
#  [1 1]]
# No of features:  1638
# ----------------------------------------
# Fold value =  5
# ----------------------------------------
# Accuracy Score:  0.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[0 4]
#  [0 0]]
# Optimal Feature Subset(s):
# Accuracy Score from SVM: 25.0
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40         4
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.25         4
#    macro avg       0.50      0.12      0.20         4
# weighted avg       1.00      0.25      0.40         4
#
# ----------------------------------------
# Fold value =  6
# ----------------------------------------
# Accuracy Score:  25.0
# Precision Score :  0.0
# Recall Score :  0.0
# F1 Score :  0.0
# Confusion Matrix :
# [[1 2]
#  [1 0]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-802f1f6547e9> in <module>()
#       4   print('-'*100)
#       5   allFeatures, allClasses = drive(subject_names[i])
# ----> 6   main_code(allFeatures, allClasses)
#
# <ipython-input-13-2c995020393a> in main_code(allFeatures, allClasses)
#      35     maxValAccSubsetIndicies = [index for index in range(len(validationAccuracyList)) if validationAccuracyList[index] == max(validationAccuracyList)]
#      36     maxValIndividuals = [individualList[index] for index in maxValAccSubsetIndicies]
# ---> 37     maxValSubsets = [[list(allFeatures)[index] for index in range(len(individual)) if individual[index] == 1] for individual in maxValIndividuals]
#      38     acc_list, prec_list, recall_list, f1_list, nooffeatures, conf_mat_list = [], [], [], [], [], []
#      39     print('Optimal Feature Subset(s):')
#
# <ipython-input-13-2c995020393a> in <listcomp>(.0)
#      35     maxValAccSubsetIndicies = [index for index in range(len(validationAccuracyList)) if validationAccuracyList[index] == max(validationAccuracyList)]
#      36     maxValIndividuals = [individualList[index] for index in maxValAccSubsetIndicies]
# ---> 37     maxValSubsets = [[list(allFeatures)[index] for index in range(len(individual)) if individual[index] == 1] for individual in maxValIndividuals]
#      38     acc_list, prec_list, recall_list, f1_list, nooffeatures, conf_mat_list = [], [], [], [], [], []
#      39     print('Optimal Feature Subset(s):')
#
# <ipython-input-13-2c995020393a> in <listcomp>(.0)
#      35     maxValAccSubsetIndicies = [index for index in range(len(validationAccuracyList)) if validationAccuracyList[index] == max(validationAccuracyList)]
#      36     maxValIndividuals = [individualList[index] for index in maxValAccSubsetIndicies]
# ---> 37     maxValSubsets = [[list(allFeatures)[index] for index in range(len(individual)) if individual[index] == 1] for individual in maxValIndividuals]
#      38     acc_list, prec_list, recall_list, f1_list, nooffeatures, conf_mat_list = [], [], [], [], [], []
#      39     print('Optimal Feature Subset(s):')
#
# KeyboardInterrupt:

# %%
for i in range(15, 32):
  print('-'*100)
  print("Subject No: ", subject_names[i])
  print('-'*100)
  allFeatures, allClasses = drive(subject_names[i])
  main_code(allFeatures, allClasses)

# %%
for i in range(20, 32):
  print('-'*100)
  print("Subject No: ", subject_names[i])
  print('-'*100)
  allFeatures, allClasses = drive(subject_names[i])
  main_code(allFeatures, allClasses)

# %%
for i in range(27, 32):
  print('-'*100)
  print("Subject No: ", subject_names[i])
  print('-'*100)
  allFeatures, allClasses = drive(subject_names[i])
  main_code(allFeatures, allClasses)

# %% [markdown]
# # Result Analysis

# %%
import numpy as np
accuracy = [95, 72.5, 97.5, 97.5, 85, 85, 95, 82.5, 85, 87.5, 87.5, 92.5, 92.5, 92.5, 92.5, 67.5, 87.5, 87.5, 92.5, 97.5, 87.5, 77.5, 95, 
            95, 92.5, 87.5, 87.5, 90, 97.5, 82.5, 90, 87.5]
accuracy  = np.array(accuracy)
print(accuracy.shape)
print(np.mean(accuracy))
print(np.std(accuracy))
# Out:
# (32,)
# 88.828125
# 6.902908552514295

# %% [markdown]
# **precision**

# %%
precision = [95, 70.833, 100, 100, 78.333, 83.333, 96.667, 80.833, 89.167, 97.5, 95, 90, 95, 91.667, 95, 75, 80, 95, 95, 100, 100,
             78.333, 94.167, 96.667, 100, 91.667, 89.167, 92.5, 100, 85.167, 90.833, 81.667]
precision  = np.array(precision)
print(precision.shape)
print(np.mean(precision))
print(np.std(precision))
# Out:
# (32,)
# 90.73440625
# 8.091339995866626

# %% [markdown]
# **Recall**

# %%
recall = [95, 100, 95, 95, 100, 100, 97.5, 97.5, 88.333, 88.333, 85.833, 97.5, 90, 95, 92.5, 85, 100, 85, 91.667, 97.5, 81.667, 85.833,
          100, 96.667, 88.333, 89.167, 96.667, 92.5, 96.667, 87.5, 96.667, 97.5]
recall = np.array(recall)
print(recall.shape)
print(np.mean(recall))
print(np.std(recall))
# Out:
# (32,)
# 93.30731250000001
# 5.284841402761653

# %% [markdown]
# **F1-Score**

# %%
f1 = [93.334, 80, 96.667, 96.667, 85.667, 88.81, 96.6, 85.267, 88.267, 90.743, 87.905, 91.905, 90, 91.267, 91.905, 73.97,
      86.333, 87.333, 93, 98.627, 88, 77.933, 96.571, 96, 92.667, 89.933, 91.238, 90.505, 98, 83.476, 92.571, 86.572]
f1 = np.array(f1)
print(f1.shape)
print(np.mean(f1))
print(np.std(f1))
# Out:
# (32,)
# 89.92915625
# 5.663418513304127
